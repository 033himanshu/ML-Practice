# %%
import pandas as pd

# %%
terrorism_df=pd.read_csv('terrorismData.csv')

# %%
df=terrorism_df.copy()

# %%
df.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   Latitude   Longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# ...

# %%
jAkState=df[df['State']=='Jammu and Kashmir']
df['Attacks']=jAkState['Killed']+jAkState['Wounded'] 
df[df['Attacks'].max()==df['Attacks']]
# Out:
#        Year  Month  Day Country              State      Region      City  \
# 70784  2000      8    1   India  Jammu and Kashmir  South Asia  Pahalgam
#
#         Latitude  Longitude     AttackType  Killed  Wounded  \
# 70784  34.016075   75.31498  Armed Assault    35.0     94.0
#
#                                                   Target  \
# 70784  Civilians traveling to a shrine close to Pahal...
#
#                                                  Summary    Group  \
# 70784  08/01/2000: Thirty-five people were gunned by ...  Unknown
#
#                        Target_type Weapon_type  Attacks
# 70784  Private Citizens & Property    Firearms    129.0

# %%
df['Attacks']=df['Killed']+df['Wounded']

# %%
df[df['Attacks'].max()==df['Attacks']]
# Out:
#        Year  Month  Day        Country     State         Region  \
# 73126  2001      9   11  United States  New York  North America
# 73127  2001      9   11  United States  New York  North America
#
#                 City   Latitude  Longitude AttackType  Killed  Wounded  \
# 73126  New York City  40.697132 -73.931351  Hijacking  1384.0   8190.0
# 73127  New York City  40.697132 -73.931351  Hijacking  1383.0   8191.0
#
#                                                   Target  \
# 73126  Passengers and crew members on American Airlin...
# 73127  Passengers and crew members on United Airlines...
#
#                                                  Summary     Group  \
# 73126  09/11/2001: This was one of four related attac...  Al-Qaida
# 73127  09/11/2001: This was one of four related attac...  Al-Qaida
#
#                        Target_type  \
# 73126  Private Citizens & Property
# 73127  Private Citizens & Property
#
# ...

# %%
df[df['Killed'].max()==df['Killed']]
# Out:
#         Year  Month  Day Country    State                      Region    City  \
# 133518  2014      6   12    Iraq  Saladin  Middle East & North Africa  Tikrit
#
#          Latitude  Longitude                   AttackType  Killed  Wounded  \
# 133518  34.621521  43.668377  Hostage Taking (Kidnapping)  1570.0      NaN
#
#           Target                                            Summary  \
# 133518  Soldiers  06/12/2014: Assailants abducted approximately ...
#
#                                               Group Target_type Weapon_type  \
# 133518  Islamic State of Iraq and the Levant (ISIL)    Military    Firearms
#
#         Attacks
# 133518      NaN

# %%
india=df[df['Country']=='India']
year=india[india['Year']>=2014]
year
# Out:
#         Year  Month  Day Country              State      Region  \
# 125343  2014      1    1   India            Manipur  South Asia
# 125344  2014      1    1   India            Manipur  South Asia
# 125366  2014      1    1   India            Haryana  South Asia
# 125373  2014      1    1   India             Odisha  South Asia
# 125374  2014      1    1   India       Chhattisgarh  South Asia
# ...      ...    ...  ...     ...                ...         ...
# 181663  2017     12   30   India             Kerala  South Asia
# 181665  2017     12   30   India       Chhattisgarh  South Asia
# 181672  2017     12   31   India  Jammu and Kashmir  South Asia
# 181684  2017     12   31   India              Assam  South Asia
# 181689  2017     12   31   India            Manipur  South Asia
#
#                  City   Latitude  Longitude                      AttackType  \
# 125343      Singjamei  24.798346  93.940430               Bombing/Explosion
# ...

# %%
# year[year['Month']<5].index
year.drop(year[year['Month']<5].index,inplace=True)
# Out:
# C:\Users\himan\AppData\Local\Temp\ipykernel_64712\2283493557.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   year.drop(year[year['Month']<5].index,inplace=True)

# %%
# year[year['Month']<5].index
year.drop(year[year['Day']<26].index,inplace=True)
# Out:
# C:\Users\himan\AppData\Local\Temp\ipykernel_64712\4037387856.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   year.drop(year[year['Day']<26].index,inplace=True)

# %%
year
# Out:
#         Year  Month  Day Country              State      Region  \
# 132468  2014      5   26   India     Andhra Pradesh  South Asia
# 132496  2014      5   26   India        West Bengal  South Asia
# 132502  2014      5   26   India        West Bengal  South Asia
# 132526  2014      5   27   India  Jammu and Kashmir  South Asia
# 132555  2014      5   27   India             Odisha  South Asia
# ...      ...    ...  ...     ...                ...         ...
# 181663  2017     12   30   India             Kerala  South Asia
# 181665  2017     12   30   India       Chhattisgarh  South Asia
# 181672  2017     12   31   India  Jammu and Kashmir  South Asia
# 181684  2017     12   31   India              Assam  South Asia
# 181689  2017     12   31   India            Manipur  South Asia
#
#                  City   Latitude  Longitude                      AttackType  \
# 132468    Bandlapalli  14.714739  77.810281               Bombing/Explosion
# ...

# %%
print(f"Attack After 26 May 2014 : {len(year)}")
# Out:
# Attack After 26 May 2014 : 478

# %%
import numpy as np
year[year['Group']=='Unknown']=np.nan
year.dropna()
# Out:
# C:\Users\himan\AppData\Local\Temp\ipykernel_64712\3245637318.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   year[year['Group']=='Unknown']=np.nan
#           Year  Month   Day Country              State      Region  \
# 132559  2014.0    5.0  27.0   India          Meghalaya  South Asia
# 132600  2014.0    5.0  28.0   India       Chhattisgarh  South Asia
# 132604  2014.0    5.0  28.0   India             Odisha  South Asia
# 132605  2014.0    5.0  28.0   India             Odisha  South Asia
# 132673  2014.0    5.0  29.0   India        Maharashtra  South Asia
# ...        ...    ...   ...     ...                ...         ...
# 181606  2017.0   12.0  28.0   India              Bihar  South Asia
# ...

# %%
set(year['Group'])
# Out:
# {"A'chik Matgrik Elite Force (AMEF)",
#  'Achik National Cooperative Army (ANCA)',
#  'Achik National Volunteer Council-B (ANVC-B)',
#  "Achik Songna An'pachakgipa Kotok (ASAK)",
#  'Bharatiya Janata Party',
#  'Communist Party of India - Maoist (CPI-Maoist)',
#  'Garo National Liberation Army',
#  'Gorkha Janmukti Morcha (GJM)',
#  'Gorkha Liberation Army (GLA)',
#  'Hizbul Mujahideen (HM)',
#  'Jaish-e-Mohammad (JeM)',
#  'Jharkhand Prastuti Committee (JPC)',
#  'Kangleipak Communist Party (KCP)',
#  'Khasi Students Union',
#  'Kuki Tribal Militants',
#  'Lama Group',
#  'Lashkar-e-Islam (India)',
#  'Lashkar-e-Taiba (LeT)',
#  "Manipur Naga People's Army (MNPA)",
#  'Maoists',
#  'National Democratic Front of Bodoland (NDFB)',
#  'National Liberation Front of Tripura (NLFT)',
#  'National Socialist Council of Nagaland-Isak-Muivah (NSCN-IM)',
#  'National Socialist Council of Nagaland-Khaplang (NSCN-K)',
#  'National Socialist Council of Nagaland-Khole-Kitovi (NSCN-KK)',
# ...

# %%
year.groupby(['Group']).size().max()
# Out:
# 110
